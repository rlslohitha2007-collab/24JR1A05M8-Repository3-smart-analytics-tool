# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files

uploaded = files.upload()

df = pd.read_csv("ecommerce_sales_dataset.csv")
# Out:
#      <input type="file" id="files-05beba6e-d1b9-409a-a4b0-27fa2dfaea30" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05beba6e-d1b9-409a-a4b0-27fa2dfaea30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#   Order_ID  Customer_Age Product_Category  Quantity   Price  Rating     City
# 0  ORD0001          58.0      Electronics         1  2353.0     3.1    Delhi
# 1  ORD0002          65.0      Electronics         5   812.0     4.0   Mumbai
# 2  ORD0003          19.0      Electronics         2  2005.0     3.8   Mumbai
# 3  ORD0004          53.0         Clothing         5  3536.0     3.1  Chennai
# 4  ORD0005          35.0      Electronics         2  3562.0     3.4    Delhi

# %%
df.tail()
# Out:
#    Order_ID  Customer_Age Product_Category  Quantity   Price  Rating  \
# 95  ORD0096          63.0         Clothing         1  3498.0     3.5
# 96  ORD0097          47.0            Books         1  1794.0     4.6
# 97  ORD0098          55.0      Electronics         5  3216.0     3.7
# 98  ORD0099          37.0            Books         4  4509.0     4.4
# 99  ORD0100          56.0         Clothing         4  1897.0     3.2
#
#          City
# 95    Chennai
# 96  Hyderabad
# 97  Bengaluru
# 98    Chennai
# 99  Hyderabad

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          100 non-null    object
#  1   Customer_Age      99 non-null     float64
#  2   Product_Category  100 non-null    object
#  3   Quantity          100 non-null    int64
#  4   Price             99 non-null     float64
#  5   Rating            99 non-null     float64
#  6   City              100 non-null    object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 5.6+ KB

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Age', 'Product_Category', 'Quantity', 'Price',
#        'Rating', 'City'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Customer_Age        1
# Product_Category    0
# Quantity            0
# Price               1
# Rating              1
# City                0
# dtype: int64

# %%
df.shape
# Out:
# (100, 7)

# %%
df.describe()
# Out:
#        Customer_Age    Quantity        Price     Rating
# count     99.000000  100.000000    99.000000  99.000000
# mean      42.606061    2.960000  2631.202020   3.686869
# std       14.087785    1.392041  1400.249708   0.749782
# min       18.000000    1.000000   455.000000   2.500000
# 25%       30.500000    2.000000  1481.500000   3.100000
# 50%       44.000000    3.000000  2285.000000   3.600000
# 75%       55.000000    4.000000  3719.000000   4.400000
# max       65.000000    5.000000  4985.000000   5.000000

# %%
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Electronics    28
# Home           21
# Books          20
# Clothing       17
# Sports         14
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# Chennai      28
# Delhi        19
# Bengaluru    19
# Mumbai       18
# Hyderabad    16
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(df['Price'], bins=20)
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Rating'], bins=10)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(df['Price'], df['Rating'])
plt.xlabel('Price')
plt.ylabel('Rating')
plt.title('Price vs Rating')
plt.show()

# %%
plt.scatter(df['Customer_Age'], df['Price'])
plt.xlabel('Customer Age')
plt.ylabel('Price')
plt.title('Age vs Price')
plt.show()

# %%
import seaborn as sns

numeric = df[['Customer_Age','Quantity','Price','Rating']]
sns.heatmap(numeric.corr(), annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
category_sales = df.groupby('Product_Category')['Price'].mean()
category_sales.plot(kind='bar')
plt.title('Average Price by Product Category')
plt.show()

# %%
df['City'].value_counts().plot(kind='bar')
plt.title('Orders by City')
plt.show()
